# %% [markdown]
# DATA PROCESSING WITH PYTHON

# %%
# Importing libs
import pandas as pd
import pandera as pa
import numpy

# %%
# Specify the path to the CSV file(local)
file_path = r'C:\Users\aska_\CovidProject\datasets\raw\covid_data.csv'

# Loading CSV file into a DataFrame
df = pd.read_csv(file_path, encoding= 'UTF-8')

# %%
# Backup of the original Dataframe
df
backup1 = df.copy()

# %%
# Visualizing the DataFrame
df
# Out:
#                            date continent    location  population  \
# 0       2020-05-13 00:00:00.000    Europe  Luxembourg     6476010
# 1       2020-05-14 00:00:00.000    Europe  Luxembourg     6476010
# 2       2020-05-15 00:00:00.000    Europe  Luxembourg     6476010
# 3       2020-05-16 00:00:00.000    Europe  Luxembourg     6476010
# 4       2020-05-17 00:00:00.000    Europe  Luxembourg     6476010
# ...                         ...       ...         ...         ...
# 337783  2020-05-08 00:00:00.000    Europe  Luxembourg     6476010
# 337784  2020-05-09 00:00:00.000    Europe  Luxembourg     6476010
# 337785  2020-05-10 00:00:00.000    Europe  Luxembourg     6476010
# 337786  2020-05-11 00:00:00.000    Europe  Luxembourg     6476010
# 337787  2020-05-12 00:00:00.000    Europe  Luxembourg     6476010
#
#         total_cases  new_cases  total_deaths  new_deaths  \
# 0           30170.0        0.0         830.0         0.0
# 1           30170.0        0.0         830.0         0.0
# 2           30170.0        0.0         830.0         0.0
# 3           30170.0        0.0         830.0         0.0
# 4           30430.0      260.0         830.0         0.0
# ...             ...        ...           ...         ...
# 337783      29870.0        0.0         830.0         0.0
# 337784      29870.0        0.0         830.0         0.0
# 337785      30170.0      300.0         830.0         0.0
# 337786      30170.0        0.0         830.0         0.0
# 337787      30170.0        0.0         830.0         0.0
#
#         total_cases_per_million  new_cases_per_million  ...  median_age  \
# 0                     4658733.0                    0.0  ...       397.0
# 1                     4658733.0                    0.0  ...       397.0
# 2                     4658733.0                    0.0  ...       397.0
# 3                     4658733.0                    0.0  ...       397.0
# 4                     4698881.0                40148.0  ...       397.0
# ...                         ...                    ...  ...         ...
# 337783                4612408.0                    0.0  ...       397.0
# 337784                4612408.0                    0.0  ...       397.0
# 337785                4658733.0                46325.0  ...       397.0
# 337786                4658733.0                    0.0  ...       397.0
# 337787                4658733.0                    0.0  ...       397.0
#
#         aged_65_older  aged_70_older  gdp_per_capita  cardiovasc_death_rate  \
# 0             14312.0         9842.0      94277965.0               128275.0
# 1             14312.0         9842.0      94277965.0               128275.0
# 2             14312.0         9842.0      94277965.0               128275.0
# 3             14312.0         9842.0      94277965.0               128275.0
# 4             14312.0         9842.0      94277965.0               128275.0
# ...               ...            ...             ...                    ...
# 337783        14312.0         9842.0      94277965.0               128275.0
# 337784        14312.0         9842.0      94277965.0               128275.0
# 337785        14312.0         9842.0      94277965.0               128275.0
# 337786        14312.0         9842.0      94277965.0               128275.0
# 337787        14312.0         9842.0      94277965.0               128275.0
#
#         diabetes_prevalence female_smokers male_smokers  \
# 0                     442.0           20,9           26
# 1                     442.0           20,9           26
# 2                     442.0           20,9           26
# 3                     442.0           20,9           26
# 4                     442.0           20,9           26
# ...                     ...            ...          ...
# 337783                442.0           20,9           26
# 337784                442.0           20,9           26
# 337785                442.0           20,9           26
# 337786                442.0           20,9           26
# 337787                442.0           20,9           26
#
#         handwashing_facilities  life_expectancy
# 0                          NaN           8225.0
# 1                          NaN           8225.0
# 2                          NaN           8225.0
# 3                          NaN           8225.0
# 4                          NaN           8225.0
# ...                        ...              ...
# 337783                     NaN           8225.0
# 337784                     NaN           8225.0
# 337785                     NaN           8225.0
# 337786                     NaN           8225.0
# 337787                     NaN           8225.0
#
# [337788 rows x 35 columns]

# %%
# Iterate through each column in the DataFrame

for coluna in df:
        # Get the unique values of the column
    valor = (df[coluna].unique())
    print("-"*20)
    msg = f"Unique values from {coluna}:"
    print(f"{msg:^20}")
    print("-"*20)
    print(f"\n{valor}\n")
    print("-"*20)
# Out:
# --------------------
# Unique values from date:
# --------------------
#
# ['2020-05-13 00:00:00.000' '2020-05-14 00:00:00.000'
#  '2020-05-15 00:00:00.000' ... '2023-09-01 00:00:00.000'
#  '2020-01-01 00:00:00.000' '2020-01-02 00:00:00.000']
#
# --------------------
# --------------------
# Unique values from continent:
# --------------------
#
# ['Europe' 'Africa' 'North America' 'Asia' nan 'Oceania' 'South America']
#
# --------------------
# --------------------
# Unique values from location:
# --------------------
#
# ['Luxembourg' 'Kenya' 'Togo' 'United States' 'Estonia' 'Palestine' 'Ghana'
#  'Croatia' 'Burkina Faso' 'Bangladesh' 'Hong Kong' 'Hungary' 'Moldova'
#  'Senegal' 'South Sudan' 'Afghanistan' 'Africa' 'Russia' 'Nicaragua'
#  'Yemen' 'Zambia' 'Burundi' 'Rwanda' 'Eswatini' 'Tokelau' 'Spain' 'Cuba'
#  'Gibraltar' 'Niger' 'Kiribati' 'Serbia' 'United States Virgin Islands'
#  'Barbados' 'Macao' 'Albania' 'Monaco' 'Iceland' 'Cambodia' 'Panama'
#  'Zimbabwe' 'Ethiopia' 'Saint Barthelemy' 'Greece' 'Madagascar' 'Curacao'
#  'Sri Lanka' 'Tonga' 'Nigeria' 'Belarus' 'Algeria' 'Kosovo' 'Seychelles'
#  'Cameroon' 'India' 'Upper middle income' 'Mongolia' 'Papua New Guinea'
#  'Europe' 'Cyprus' 'Saint Helena' 'Malawi' 'Greenland' 'Belgium'
#  'American Samoa' 'Niue' 'Sudan' 'Trinidad and Tobago' 'Kuwait' 'Canada'
#  'Sierra Leone' 'Montenegro' 'Indonesia' 'Uruguay' 'European Union'
#  'Paraguay' 'Czechia' 'Grenada' 'Belize' 'Saint Kitts and Nevis' 'Andorra'
#  'Malaysia' 'Cape Verde' 'Kyrgyzstan' 'North America' 'Suriname' 'Tunisia'
#  'Iran' 'Montserrat' 'Singapore' 'Faeroe Islands'
#  'Democratic Republic of Congo' 'Benin' 'Peru' 'Uzbekistan' 'Guadeloupe'
#  'Angola' 'Maldives' 'Cayman Islands' 'Saint Lucia' 'Laos' 'North Korea'
#  'Iraq' 'Sweden' 'Falkland Islands' 'Morocco' 'Turkey' 'Denmark'
#  'Sint Maarten (Dutch part)' 'Bermuda' 'Anguilla' 'Philippines' 'Guam'
#  'Vanuatu' 'Mali' 'Central African Republic' 'Saint Martin (French part)'
#  'Latvia' 'North Macedonia' 'Ireland' 'Fiji' 'Djibouti' 'Mozambique'
#  'Bhutan' 'Antigua and Barbuda' 'Switzerland' 'Turkmenistan' 'Slovakia'
#  'Guatemala' 'Pitcairn' 'Chad' 'Malta' 'Lebanon' 'Vatican'
#  'Saint Pierre and Miquelon' 'Isle of Man' 'Finland' 'Bolivia'
#  'Northern Cyprus' 'Dominica' 'Argentina' 'Myanmar' 'Guernsey' 'Syria'
#  'Chile' 'Turks and Caicos Islands' 'Northern Ireland' 'Slovenia' 'Poland'
#  'Marshall Islands' 'Israel' 'Lesotho' 'France' 'Armenia' 'Venezuela'
#  'Bonaire Sint Eustatius and Sab' 'Dominican Republic'
#  'Saint Vincent and the Grenadin' 'Namibia' 'Guinea' 'China' 'Taiwan'
#  'Northern Mariana Islands' 'Solomon Islands' 'Portugal' 'Martinique'
#  'Tuvalu' 'Aruba' 'Bosnia and Herzegovina' 'French Guiana' 'Liberia'
#  'Ecuador' 'Italy' 'Samoa' 'Vietnam' 'Colombia' 'Guinea-Bissau' 'Nauru'
#  'Norway' 'Tajikistan' 'Botswana' 'Puerto Rico' 'Asia' 'Somalia'
#  'Mauritania' 'Libya' 'Uganda' 'Jamaica' 'Egypt' 'French Polynesia'
#  'Comoros' 'San Marino' 'Guyana' 'Nepal' 'Wales' 'Australia' 'Brazil'
#  'Oceania' 'Mauritius' 'El Salvador' 'Tanzania' 'Gabon' 'Japan' 'Qatar'
#  'Liechtenstein' 'South Africa' 'Ukraine' 'Congo' 'Haiti'
#  'Sao Tome and Principe' 'Netherlands' 'Austria' 'Wallis and Futuna'
#  'British Virgin Islands' 'Gambia' 'Oman' 'Mayotte' 'England' 'Jersey'
#  'Lithuania' 'Thailand' 'Reunion' 'Cook Islands' 'South America'
#  'High income' 'United Arab Emirates' 'Azerbaijan' 'Saudi Arabia'
#  'New Caledonia' 'Brunei' 'Equatorial Guinea' 'Western Sahara' 'World'
#  'Georgia' 'Jordan' 'Costa Rica' 'Low income' 'Mexico' 'Pakistan'
#  'Romania' 'Honduras' 'South Korea' 'Timor' 'Bahamas' 'Bulgaria'
#  'United Kingdom' 'Scotland' 'New Zealand' 'Eritrea' 'Germany'
#  "Cote d'Ivoire" 'Micronesia (country)' 'Kazakhstan' 'Palau'
#  'Lower middle income' 'Bahrain']
#
# --------------------
# --------------------
# Unique values from population:
# --------------------
#
# [    6476010   540274840    88487000  3382898560    13260640    52500760
#    334758700    40303610   226737640  1711863680    74888630    99673040
#     32729930   173164520   109131720   411287720 14267366140  1447133120
#     69483950   336966120   200176700   128895830   137767020    12016800
#        18930   475586320   112121980      326770   262079820     1312370
#     68715470      994790     2816460     6951800    28423180      364910
#      3729030   167678510    44085820   163205390  1233799280      109940
#    103849720   296117180     1911730   218321500     1068670  2185412160
#     95349560   449032280    17821150     1071350   279145420 14171731200
#  25259213000    33983730   101426250  7448078030     8960070       54010
#    204053180      564940   116559230      442950       19520   468742000
#     15310430    42688860   384543280    86057230     6270820  2755013440
#     34227960  4501467930    67807450   104939900     1254590     4052850
#       476810      798430   339382160     5931620    66306210  6003236570
#      6180460   123561160   885505680       44130    56370220      531170
#    990102160   133528640   340495880   346276480     3957620   355889960
#      5237980      687220     1798720    75294770   260694160   444961240
#    105493490       38010   374579760   853412480    58822590      441920
#       642070      158770  1155590080     1717830     3267440   225935980
#     55791480      318160    18506540    20936060    50231080     9297690
#     11208510   329695200     7824570      937720    87404710    64307770
#     56434550   178439140         470   177233120     5332930    54897440
#         8080       58850      845340    55407450   122241140     3828360
#       727580   455103240   541793120      633290   221252420   196037360
#       457260    18960000    21198430   398571440      415930    94490000
#     23058260   678130000    27804720   283017000      270520   112288210
#      1039590    25670240   138593490 14258873600   238933960      495740
#      7242720   102708570     3675120      113350     1064590    32335300
#      3045680    53026900   180010020   590374720     2223900   981868560
#    518740280    21055800      126910    54343240    99527890    26303000
#     32524120 47213833700   175975080    47361460    68123440   472495880
#     28273820  1109900960     3062920     8367830      336900     8087270
#    305475860    31700000   261774100  2153135040   450388600    12994780
#     63363930   654977520    23889970  1239516960    26951310      393550
#    598938840   397017440    59704300   115850030     2273930   175640200
#     89396170      115960      313320    27059950    45763000     3261130
#    565500000     1107960    27500580   716970240     9740620      170320
#   4368166790 12505146000    94411380   103580780   364088240     2899590
#      4490020    16749160     5760050 79751050240    37443850   112858750
#     51808360  7376049000  1275041200  2358248640   196592700   104328580
#    518158080    13412980     4099890    67819550   675089360    54660000
#     51852890    36840410   833698400   281605480     1141780   193979980
#       180840 34320973000    14722370]
#
# --------------------
# --------------------
# Unique values from total_cases:
# --------------------
#
# [  30170.   30430.   30750. ... 2236060. 2236780. 2236900.]
#
# --------------------
# --------------------
# Unique values from new_cases:
# --------------------
#
# [    0.   260.   320. ... 74090. 62020. 50380.]
#
# --------------------
# --------------------
# Unique values from total_deaths:
# --------------------
#
# [  830.   870.   900. ... 79080. 79150. 79300.]
#
# --------------------
# --------------------
# Unique values from new_deaths:
# --------------------
#
# [0.000e+00 4.000e+01 3.000e+01 ... 2.803e+04 5.061e+04 1.896e+04]
#
# --------------------
# --------------------
# Unique values from total_cases_per_million:
# --------------------
#
# [4658733. 4698881. 4748294. ... 4422476. 4541377. 4612408.]
#
# --------------------
# --------------------
# Unique values from new_cases_per_million:
# --------------------
#
# [     0.  40148.  49413. ... 963556. 453983. 169858.]
#
# --------------------
# --------------------
# Unique values from total_deaths_per_million:
# --------------------
#
# [128165. 134342. 138974. ... 114268. 121989. 125077.]
#
# --------------------
# --------------------
# Unique values from new_deaths_per_million:
# --------------------
#
# [    0.  6177.  4632. ... 48263. 20842. 12902.]
#
# --------------------
# --------------------
# Unique values from reproduction_rate:
# --------------------
#
# [ 69.   7.  72.  73.  75.  74.  71.  76.  79.   8.  84.  87.  91.  94.
#   98. 102. 106. 109. 113. 118. 123. 128. 131. 134. 139. 142. 146.  15.
#  155. 158. 162. 166. 171. 177. 181.  18. 178. 175. 167. 163. 161. 159.
#  157. 154. 153. 151. 149. 147. 143. 138. 127. 124. 121. 116.  11. 107.
#  104.  68.  67.  78.  81.  83.  85.  93.  95. 103. 105. 112. 115. 117.
#   12. 125. 145. 148. 144. 141.  14. 135. 132.  13. 129. 114. 111. 108.
#  101.  10.  97.  96.  92.   9.  89.  88.  77.  65.  64.  61.   6.  59.
#   62.  63.  66.  86.  82.  99. 119. 122. 126. 133. 137. 152.  nan 174.
#   58.  57.  55.  56. 136.  17. 168. 165.  16. 156. 164.  54.  53.  52.
#   51.   5.  49.  48.  46.  44.  42.   4.  38.  36.  34.  33.  31.   3.
#   28.  27.  26.  25.  23.  22.  21.   2.  19.   1. 182. 192.  20. 207.
#  211. 209. 208. 203. 199. 194. 188. 183. 176. 221. 233. 244. 249. 248.
#  243. 238. 231. 223. 216. 205. 193. 187. 179. 191. 195. 213. 189.  39.
#   37. 169.  47.  45.  43.  41.  35.  24.  29.  32. 184. 185. 186. 172.
#  232. 246. 263. 286. 287. 278.   0. 219. 222. 225. 196. 204. 173. 292.
#  293. 294. 296. 295. 288. 279. 269. 262. 254. 241. 235. 267. 283. 281.
#  272. 268. 257. 245. 227. 215. 197. 198. 212. 214. 202. 228. 239. 224.
#  234. 237. 242. 217. 264. 335. 383.  40. 395. 381. 357. 337. 326. 317.
#  308. 201.  -2.  -1.  -3. 255. 247. 229. 265. 251. 256. 271. 291. 253.
#  206. 226. 259. 218. 261. 236. 252. 482. 461. 465. 437. 388. 316. 258.
#  273. 277. 282. 289. 285. 425. 421. 407. 364. 352. 343. 327. 304. 266.
#  325. 391. 422. 408. 385. 361. 362. 376. 372. 347. 318. 276. 323. 354.
#  346. 303. 297. 274. 275. 306. 309. 328. 359. 366. 368. 329. 305.  -7.
#  344. 336. 313. 298. 371. 403. 314. 315. 332. 348. 355. 358. 587. 557.
#  312. 299.  30. 284.  -4.  -6. 356. 342. 341. 338. 321.]
#
# --------------------
# --------------------
# Unique values from icu_patients:
# --------------------
#
# [  11   15   13 ... 9120 8907 8775]
#
# --------------------
# --------------------
# Unique values from total_tests:
# --------------------
#
# [56879 58172 59446 ... 53235 54282 55673]
#
# --------------------
# --------------------
# Unique values from new_tests:
# --------------------
#
# [ 1206  1293  1274 ...  9307 10358  1962]
#
# --------------------
# --------------------
# Unique values from positive_rate:
# --------------------
#
# ['0,005' '0,006' '0,007' ... '0,5939' '0,5821' '0,5851']
#
# --------------------
# --------------------
# Unique values from tests_units:
# --------------------
#
# ['tests performed' nan 'people tested' 'samples tested' 'units unclear']
#
# --------------------
# --------------------
# Unique values from total_vaccinations:
# --------------------
#
# [       0  2734547  2757575 ... 20463361 20472584 20536427]
#
# --------------------
# --------------------
# Unique values from people_fully_vaccinated:
# --------------------
#
# [       0  1145453 45428572 ... 16607637 16611044 16661209]
#
# --------------------
# --------------------
# Unique values from total_boosters:
# --------------------
#
# [      0   40962   54353 ... 2073609 2074900 2087899]
#
# --------------------
# --------------------
# Unique values from new_vaccinations:
# --------------------
#
# [      0 2282423 2893755 ...  148076  257988   71260]
#
# --------------------
# --------------------
# Unique values from total_vaccinations_per_hundred:
# --------------------
#
# ['0' '30,9' '31,16' ... '121,9' '122,94' '35,85']
#
# --------------------
# --------------------
# Unique values from people_vaccinated_per_hundred:
# --------------------
#
# ['0' '17,51' '17,61' ... '92,35' '17,43' '41,3']
#
# --------------------
# --------------------
# Unique values from people_fully_vaccinated_per_hundred:
# --------------------
#
# ['0' '12,94' '13,68' ... '44,18' '47,18' '89,86']
#
# --------------------
# --------------------
#  539849. 344094. 430548. 270113. 109361. 145183.  33143. 266342. 342989.
#  109861.  31784. 559812. 259538. 201285. 202812.  23307. 496218. 208257.
#  137973. 152783. 423031. 370946. 240208.  85998. 335346. 235954. 424688.
#  122137. 128797.  31111. 156139.  30374. 454343. 466792. 151689.]
#
# --------------------
# --------------------
# Unique values from diabetes_prevalence:
# --------------------
#
# [ 442.  292.  615. 1079.  402. 1059.  497.  559.  242.  838.  833.  755.
#   572. 1043.  959.   nan  618. 1147.  535.  394.  605.  428.  717.  827.
#  2266. 1008. 1226. 1357.  546.  531.   40.  182.  747.  455. 1162. 1068.
#  1542.  518.  673. 1055.   72. 1039.  482. 1765.  924.  216.  429. 1567.
#  1097. 1584.  737.  632.  693.  682. 1071. 1711. 1284.  797. 1674.  711.
#  1254.  852. 1099.   61.   99.  595.  757.  919. 1322.  883.  479.  714.
#  1213.  641.  130.  707. 2152. 1202.  491.  328. 1449.   33.  975. 1317.
#   729. 1018. 1271.  576.  689.   55.  461.  846.  725.  591. 3053.  674.
#   477.  647.   82.  974. 1868.  985. 2725.  555.  478.  921.   60.  744.
#  2407.  481.  129.   25. 1128. 1731. 2263. 1188.  564.  726.  507.  811.
#  2202.  887.  575. 1652.  777.  552.  665.  529.  635. 1367.  191. 1261.
#   367.  704. 1726. 1772. 2336. 1279.  778.  851. 1175.  878. 1306.  835.
#   721.   68.  686.  581.  808.  831. 1589.]
#
# --------------------
# --------------------
# Unique values from female_smokers:
# --------------------
#
# ['20,9' '1,2' '0,9' '19,1' '24,5' '0' '0,3' '34,3' '1,6' '1' '26,8' '5,9'
#  '0,4' '23,4' '7,6' '3,1' '4,7' '1,7' '27,4' '17,1' '0,1' '35,9' '37,7'
#  '1,9' '7,1' '14,3' '2' '2,4' '35,3' '11,8' '0,6' '10,5' '0,7' '5,5'
#  '23,5' '19,6' '4,4' '25,1' '2,7' '12' '8,8' '44' '2,8' '14' '5' '30,5'
#  '29' '2,1' '3,6' '7,4' '1,1' '0,8' '5,2' '4,8' '1,3' '7,3' '18,8' '14,1'
#  '19,3' '7,8' '25,6' '23' '10,2' '5,1' '22,6' '23,1' '26,9' '18,3' '16,2'
#  '6,3' '34,2' '20,1' '23,3' '15,4' '30,1' '1,5' '8,5' '9,7' '16,3' '30,2'
#  '19,8' '16,7' '43' '5,7' '3,4' '5,3' '0,2' '9,5' '13' '10,1' '3,2' '2,5'
#  '3,3' '11,2' '8,1' '13,5' '2,9' '24,4' '28,4' '0,5' '21,3' '1,8' '6,434'
#  '6,4' '6,9' '22,9' '6,2' '20' '14,8' '28,2' '7' '7,7' '5,8']
#
# --------------------
# --------------------
# Unique values from male_smokers:
# --------------------
#
# ['26' '20,4' '14,2' '24,6' '39,3' '0' '7,7' '39,9' '23,9' '44,7' '34,8'
#  '44,6' '16,6' '58,3' '29,2' '24,7' '21' '16,5' '31,4' '53,3' '15,4'
#  '58,9' '40,2' '14,5' '51,2' '15,2' '33,7' '9,9' '30,7' '8,5' '52' '27'
#  '44,4' '10,8' '46,1' '30,4' '35,7' '20,6' '46,5' '48,8' '52,7' '37'
#  6337. 7447. 7199. 7766. 6432. 8497. 6991. 7078. 8344. 7588. 7499. 6546.
#  6647. 8463. 8023. 8249. 6413. 6457.  640. 7039. 8228. 8154. 7994. 7907.
#  6205. 7786. 7946. 7593. 7715. 8048. 7625. 7797. 7513. 7755. 7586. 5874.
#  7026. 7377. 7453. 8028. 7505. 6727. 7605. 7527. 8303.  695. 7392. 8229.
#  6632. 8133. 5778. 6788.  736.]
#
# --------------------

# %%
# Display information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337788 entries, 0 to 337787
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   date                                 337788 non-null  object
#  1   continent                            321741 non-null  object
#  2   location                             337788 non-null  object
#  3   population                           337788 non-null  int64
#  4   total_cases                          300132 non-null  float64
#  5   new_cases                            328555 non-null  float64
#  6   total_deaths                         278839 non-null  float64
#  7   new_deaths                           328611 non-null  float64
#  8   total_cases_per_million              300132 non-null  float64
#  9   new_cases_per_million                328555 non-null  float64
#  10  total_deaths_per_million             278839 non-null  float64
#  11  new_deaths_per_million               328611 non-null  float64
#  12  reproduction_rate                    184817 non-null  float64
#  13  icu_patients                         337788 non-null  int64
#  14  total_tests                          337788 non-null  int64
#  15  new_tests                            337788 non-null  int64
#  16  positive_rate                        337788 non-null  object
#  17  tests_units                          106788 non-null  object
#  18  total_vaccinations                   337788 non-null  int64
#  19  people_fully_vaccinated              337788 non-null  int64
#  20  total_boosters                       337788 non-null  int64
#  21  new_vaccinations                     337788 non-null  int64
#  22  total_vaccinations_per_hundred       337788 non-null  object
#  23  people_vaccinated_per_hundred        337788 non-null  object
#  24  people_fully_vaccinated_per_hundred  337788 non-null  object
#  25  median_age                           266631 non-null  float64
#  26  aged_65_older                        257294 non-null  float64
#  27  aged_70_older                        263959 non-null  float64
#  28  gdp_per_capita                       261302 non-null  float64
#  29  cardiovasc_death_rate                261866 non-null  float64
#  30  diabetes_prevalence                  275203 non-null  float64
#  31  female_smokers                       337788 non-null  object
#  32  male_smokers                         337788 non-null  object
#  33  handwashing_facilities               128264 non-null  float64
#  34  life_expectancy                      310719 non-null  float64
# dtypes: float64(17), int64(8), object(10)
# memory usage: 90.2+ MB

# %% [markdown]
# Processing, cleaning, etc

# %%
# Change column type to datetime64[ns] for column: 'date'
df = df.astype({'date': 'datetime64[ns]'})

# Changing the type from objetc to numeric for columns that are numeric
df['male_smokers'] = pd.to_numeric(df['male_smokers'], errors='coerce')
df['female_smokers'] = pd.to_numeric(df['female_smokers'], errors='coerce')


# Drop missing values from continent column

df = df.dropna(subset=['continent'])

# Drop columns that will not be used in the analysis
df = df.drop(columns=['total_cases_per_million', 'new_cases_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 
                      'total_tests', 'new_tests', 'positive_rate', 'tests_units', 'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred', 
                      'people_fully_vaccinated_per_hundred', 'gdp_per_capita','aged_70_older' ])

# %%
# Function to remove the last zero from a float number and handle NaN in specifics columns
# This is necessary due to an encoding issue in the table that affected some columns

def remove_ultimo_zero(numero):
    if isinstance(numero, (int, float)) and not numpy.isnan(numero) and numpy.isfinite(numero):
        return int(numero / 10)
    else:
        return 0  # Replace with another value if desired

# # Applying the function to the columns
df['total_cases'] = df['total_cases'].apply(remove_ultimo_zero)
df['population'] = df['population'].apply(remove_ultimo_zero)
df['new_cases'] = df['new_cases'].apply(remove_ultimo_zero)
df['total_deaths'] = df['total_deaths'].apply(remove_ultimo_zero)
df['new_deaths'] = df['new_deaths'].apply(remove_ultimo_zero)

# # Converting columns to integers
df['total_cases'] = df['total_cases'].astype(int)
df['population'] = df['population'].astype(int)
df['new_cases'] = df['new_cases'].astype(int)
df['total_deaths'] = df['total_deaths'].astype(int)
df['new_deaths'] = df['new_deaths'].astype(int)

# Convert columns to numeric, handling errors by coercing them to NaN
# Fill missing (NaN) values with 0
# Convert to integer type
df['aged_65_older'] = pd.to_numeric(df['aged_65_older'], errors='coerce').fillna(0).astype(int)
df['female_smokers'] = pd.to_numeric(df['female_smokers'], errors='coerce').fillna(0).astype(int)
df['male_smokers'] = pd.to_numeric(df['male_smokers'], errors='coerce').fillna(0).astype(int)
df['female_smokers'] = pd.to_numeric(df['female_smokers'], errors='coerce').fillna(0).astype(int)
df['life_expectancy'] = pd.to_numeric(df['life_expectancy'], errors='coerce').fillna(0).astype(int)
df['cardiovasc_death_rate'] = pd.to_numeric(df['cardiovasc_death_rate'], errors='coerce').fillna(0).astype(int)
df['diabetes_prevalence'] = pd.to_numeric(df['diabetes_prevalence'], errors='coerce').fillna(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 321741 entries, 0 to 337787
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   date                     321741 non-null  datetime64[ns]
#  1   continent                321741 non-null  object
#  2   location                 321741 non-null  object
#  3   population               321741 non-null  int32
#  4   total_cases              321741 non-null  int32
#  5   new_cases                321741 non-null  int32
#  6   total_deaths             321741 non-null  int32
#  7   new_deaths               321741 non-null  int32
#  8   reproduction_rate        183741 non-null  float64
#  9   icu_patients             321741 non-null  int64
#  10  total_vaccinations       321741 non-null  int64
#  11  people_fully_vaccinated  321741 non-null  int64
#  12  total_boosters           321741 non-null  int64
#  13  new_vaccinations         321741 non-null  int64
#  14  median_age               265293 non-null  float64
#  15  aged_65_older            321741 non-null  int32
#  16  cardiovasc_death_rate    321741 non-null  int32
#  17  diabetes_prevalence      321741 non-null  int32
#  18  female_smokers           321741 non-null  int32
#  19  male_smokers             321741 non-null  int32
#  20  handwashing_facilities   126926 non-null  float64
#  21  life_expectancy          321741 non-null  int32
# dtypes: datetime64[ns](1), float64(3), int32(11), int64(5), object(2)
# memory usage: 43.0+ MB

# %%
df
# Out:
#              date continent    location  population  total_cases  new_cases  \
# 0      2020-05-13    Europe  Luxembourg      647601         3017          0
# 1      2020-05-14    Europe  Luxembourg      647601         3017          0
# 2      2020-05-15    Europe  Luxembourg      647601         3017          0
# 3      2020-05-16    Europe  Luxembourg      647601         3017          0
# 4      2020-05-17    Europe  Luxembourg      647601         3043         26
# ...           ...       ...         ...         ...          ...        ...
# 337783 2020-05-08    Europe  Luxembourg      647601         2987          0
# 337784 2020-05-09    Europe  Luxembourg      647601         2987          0
# 337785 2020-05-10    Europe  Luxembourg      647601         3017         30
# 337786 2020-05-11    Europe  Luxembourg      647601         3017          0
# 337787 2020-05-12    Europe  Luxembourg      647601         3017          0
#
#         total_deaths  new_deaths  reproduction_rate  icu_patients  ...  \
# 0                 83           0               69.0            11  ...
# 1                 83           0                7.0            11  ...
# 2                 83           0               72.0            15  ...
# 3                 83           0               73.0            13  ...
# 4                 83           0               75.0             8  ...
# ...              ...         ...                ...           ...  ...
# 337783            83           0               61.0            15  ...
# 337784            83           0               63.0            14  ...
# 337785            83           0               64.0            18  ...
# 337786            83           0               66.0            22  ...
# 337787            83           0               67.0            22  ...
#
#         total_boosters  new_vaccinations  median_age  aged_65_older  \
# 0                    0                 0       397.0          14312
# 1                    0                 0       397.0          14312
# 2                    0                 0       397.0          14312
# 3                    0                 0       397.0          14312
# 4                    0                 0       397.0          14312
# ...                ...               ...         ...            ...
# 337783               0                 0       397.0          14312
# 337784               0                 0       397.0          14312
# 337785               0                 0       397.0          14312
# 337786               0                 0       397.0          14312
# 337787               0                 0       397.0          14312
#
#         cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 0                      128275                  442               0
# 1                      128275                  442               0
# 2                      128275                  442               0
# 3                      128275                  442               0
# 4                      128275                  442               0
# ...                       ...                  ...             ...
# 337783                 128275                  442               0
# 337784                 128275                  442               0
# 337785                 128275                  442               0
# 337786                 128275                  442               0
# 337787                 128275                  442               0
#
#         male_smokers  handwashing_facilities  life_expectancy
# 0                 26                     NaN             8225
# 1                 26                     NaN             8225
# 2                 26                     NaN             8225
# 3                 26                     NaN             8225
# 4                 26                     NaN             8225
# ...              ...                     ...              ...
# 337783            26                     NaN             8225
# 337784            26                     NaN             8225
# 337785            26                     NaN             8225
# 337786            26                     NaN             8225
# 337787            26                     NaN             8225
#
# [321741 rows x 22 columns]

# %% [markdown]
# SCHEMA

# %%
# Validating schema with pandera
# Create a dictionary to store column schemas
schema_dict = {}

# Iterate through all columns in the DataFrame
for column, dtype in df.dtypes.items():
    if dtype == 'object':
        # If the data type of the column is 'object', validate as STRING and allow null values
        schema_dict[column] = pa.Column(pa.String, nullable=True)
    elif dtype == 'int64':
        # If the data type of the column is 'int64', validate as INT and allow null values
        schema_dict[column] = pa.Column(pa.Int, nullable=True)
    elif dtype == 'float64':
        # If the data type of the column is 'float64', validate as FLOAT and allow null values
        schema_dict[column] = pa.Column(pa.Float, nullable=True)
    elif dtype == 'datetime64[ns]':
        # If the data type of the column is 'datetime64[ns]', validate as DATETIME and allow null values
        schema_dict[column] = pa.Column(pa.DateTime, nullable=True)

# Create a Pandera schema based on the dictionary
schema = pa.DataFrameSchema(schema_dict)

# Validate the DataFrame based on the schema
try:
    schema.validate(df)
    print("The DataFrame is valid with the new schema.")
except pa.errors.SchemaError as e:
    print("The DataFrame is not valid. Validation errors:")
    print(e)
# Out:
# O DataFrame é válido com o novo schema.

# %% [markdown]
# VISUALIZAÇÃO

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'df' is your DataFrame with the data
# Make sure the data is loaded into the variable 'df'

# Select only numeric columns
numeric_data = df.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Filter for strong correlations (>= 0.5 or <= -0.5)
strong_correlations = correlation_matrix[(correlation_matrix >= 0.5) | (correlation_matrix <= -0.5)]

# Create the heatmap of correlations
plt.figure(figsize=(10, 8))
sns.heatmap(strong_correlations, annot=True, cmap='coolwarm', fmt=".2f")

# Add title
plt.title("Correlation Heatmap (|Correlation| >= 0.5)")

# Show the plot
plt.show()

# %% [markdown]
# LOAD

# %%
# Save as CSV
csv_file_name = 'covid_data_last.csv'
df.to_csv(csv_file_name, index=False)  # The parameter 'index=False' prevents writing the index to the CSV file
print(f'The DataFrame has been saved as "{csv_file_name}" (CSV)')
# Out:
# O DataFrame foi salvo como "covid_data_.csv" (CSV)
